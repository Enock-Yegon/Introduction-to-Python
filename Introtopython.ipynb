# %% [markdown]
# <a href="https://colab.research.google.com/github/Enock-Yegon/Introduction-to-Python/blob/main/Introtopython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("What is your age:")
# Out:
# What is your age:21

# %%
name = int(name)

# %%
type(name)
# Out:
# int

# %%
temp = float(input("What is your body temperature in Celsius:"))

fah = (temp * 1.8) + 32
print("Your body temperature in Fahrenheit is:",fah)
# Out:
# What is your body temperature in Celsius:54
# Your body temperature in Fahrenheit is: 129.2

# %%
#Mini calculator
num1 = float(input("Enter the first Number: "))
num2 = float(input("Enter the second Number: "))
print(f"The sum of the two numbers is {num1 + num2}")
print(f"The difference between the two numbers is {num1 - num2}")
print(f"The product of the two numbers is {num1 * num2}")
print(f"Num1 is more than num2 by {num1 / num2}")
print(f"The modulus of the number is {num1 % num2}")
print(f"The floor of the division of the two numbers is {num1 // num2}")
print(f"The power of num1 to num2 is {num1 ** num2}")
# Out:
# Enter the first Number: 5.4
# Enter the second Number: 4.4
# The sum of the two numbers is 9.8
# The difference between the two numbers is 1.0
# The product of the two numbers is 23.760000000000005
# Num1 is more than num2 by 1.2272727272727273
# The modulus of the number is 1.0
# The floor of the division of the two numbers is 1.0
# The power of num1 to num2 is 1669.2928885428548

# %%
age = "10"
Price = float(age)
print(Price)
# Out:
# 10.0

# %%
print(name)
# Out:
# Yegon

# %%
name = "Enock"
Age = "27"
Hobby = "Coding"
print("My name is",name)
print("I am",Age,"years old")
print("My hobby is",Hobby)
# Out:
# My name is Enock
# I am 27 years old
# My hobby is Coding
